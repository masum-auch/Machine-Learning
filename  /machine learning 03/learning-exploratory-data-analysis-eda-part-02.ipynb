# %% [markdown]
# I'm learning ML.

# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/titanic01/titanicdata.csv')

# %%
df

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df

# %%
df.head()

# %% [markdown]
# # SibSp data understanding

# %%
import seaborn as sns

# %%
sns.countplot(df['SibSp'])

# %%
print(df['SibSp'].unique())

# %%
print(df['SibSp'].isnull().sum())  # Missing value check

# %% [markdown]
# **"Initially, I tried using the code sns.countplot(df['SibSp']) for visualizing the distribution of the SibSp feature, but it didn't work as expected. After modifying the code to sns.countplot(x='SibSp', data=df), it worked perfectly, giving the correct countplot visualization."**

# %%
sns.countplot(x ='SibSp', data = df)

# %%
df['SibSp'].value_counts().plot(kind = 'pie')

# %%
print(df.dtypes)

# %%
print(df['SibSp'].dtypes)

# %%
df['SibSp'].value_counts().plot(kind = 'pie', autopct= '%.2f')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['SibSp'], bins= 10)

# %%
sns.distplot(df['SibSp'])

# %%
sns.boxplot(x= 'SibSp', data= df)

# %%
df['SibSp'].min()

# %%
df['SibSp'].max()

# %%
df['SibSp'].mean()

# %%
df['SibSp'].skew()
