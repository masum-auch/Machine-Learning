# %%
import pandas as pd

# %%
import json

# %%
import requests

# %%
from pandas import json_normalize

# %%
with open('/kaggle/input/learning-api-dataset/top_rated.json') as f:
    data = json.load(f)

# %%
df = json_normalize(data['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6      155                                The Dark Knight
# 7    19404                    Dilwale Dulhania Le Jayenge
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     122  The Lord of the Rings: The Return of the King
# 11     680                                   Pulp Fiction
# 12  372058                                     Your Name.
# 13      13                                   Forrest Gump
# 14  157336                                   Interstellar
# ...

# %%
df = pd.DataFrame(data['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
print("Total rows:", len(df))
df.head()
# Out:
# Total rows: 20
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     35.3465
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     27.3851
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     14.8967
# 3  The true story of how businessman Oskar Schind...   1993-12-15     14.0384
# 4  The defense and the prosecution have rested an...   1957-04-10      9.5669
#
#    vote_average  vote_count
# 0         8.712       29130
# 1         8.686       22005
# 2         8.571       13298
# 3         8.567       16824
# 4         8.547        9494

# %%
df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6      155                                The Dark Knight
# 7    19404                    Dilwale Dulhania Le Jayenge
# 8      497                                 The Green Mile
# 9   496243                                       Parasite
# 10     122  The Lord of the Rings: The Return of the King
# 11     680                                   Pulp Fiction
# 12  372058                                     Your Name.
# 13      13                                   Forrest Gump
# 14  157336                                   Interstellar
# ...
