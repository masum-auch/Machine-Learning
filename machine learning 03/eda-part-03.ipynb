# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/kaggle/input/titanic/titanicdata.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
sns.countplot(data= df, x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data= df, x='Survived'['Sex'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_37/3577811071.py in <cell line: 0>()
# ----> 1 sns.countplot(data= df, x='Survived'['Sex'])
#
# TypeError: string indices must be integers, not 'str'

# %%
df['SibSp'].value_counts().plot(kind= 'pie', autopct= '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(df['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.distplot(df['SibSp'], hist= False)
# Out:
# <Axes: xlabel='SibSp', ylabel='Density'>

# %%
sns.boxplot(df['SibSp'])
# Out:
# <Axes: >

# %%
sns.boxplot(data= df, x= 'SibSp')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].min()
# Out:
# 0

# %%
df['SibSp'].max()
# Out:
# 8

# %%
round(df['SibSp'].mean(),2)
# Out:
# 0.52

# %%
round(df['SibSp'].skew(), 2)
# Out:
# 3.7

# %%
sns.boxplot(data= df, x= 'Sex', y= 'Age', hue= 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tips = pd.read_csv('/kaggle/input/sns-default-datasets/tips.csv')

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', size='size', hue='sex', style= 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df, x='Pclass', y='Fare', hue='Sex', style='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # Another Practices

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(data= df, x= 'Sex', hue= 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.histplot(df['Age'], bins= 20, kde= True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.distplot(df['Age'], bins= 20)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(data= df, x= 'Pclass', y= 'Survived', hue= 'Sex')
plt.title('Survival Rate by Class and Gender')
plt.ylabel('Average Survival Rate')
# Out:
# Text(0, 0.5, 'Average Survival Rate')

# %%
tt= sns.catplot(data= df, x= 'Pclass', hue= 'Sex', col= 'Survived', kind= 'count', height= 4, aspect= 1)
tt.fig.suptitle('Survival Distribution by Class and Gender', y=1.05)
# Out:
# Text(0.5, 1.05, 'Survival Distribution by Class and Gender')

# %%
subdf = df.head(100)

# %%
sns.scatterplot(data= subdf, x= 'PassengerId', y= 'Fare', hue= 'Sex', style= 'Embarked')
# Out:
# <Axes: xlabel='PassengerId', ylabel='Fare'>

# %%
sns.barplot(data= df, x= 'Pclass', y= 'Fare', hue= 'Sex', ci= None)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(data= df, x= 'Sex', y= 'Age', hue= 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.kdeplot(df[df['Survived']==0]['Age'])
sns.kdeplot(df[df['Survived']==1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
pd.crosstab(df['Pclass'], df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
(pd.crosstab(df['Pclass'], df['Survived'], normalize= 'index')*100).round(2).astype(int)
# Out:
# Survived   0   1
# Pclass
# 1         37  62
# 2         52  47
# 3         75  24

# %%
sns.heatmap(pd.crosstab(df['Pclass'], df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby('Pclass')['Age'].mean().round(2).astype(int)
# Out:
# Pclass
# 1    38
# 2    29
# 3    25
# Name: Age, dtype: int64

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']),cmap='coolwarm', annot= True, figsize= (6, 5))

# %%
iris = pd.read_csv('/kaggle/input/sns-default-datasets/iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue= 'species')

# %%
flight = pd.read_csv('/kaggle/input/sns-default-datasets/flights.csv')

# %%
flight
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
new = flight.groupby('year').sum().reset_index()

# %%
sns.lineplot(data= new, x= 'year', y= 'passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.pairplot(df[['Age', 'Fare', 'Pclass', 'Survived']], hue='Survived')

# %%
sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <Axes: xlabel='year', ylabel='month'>
